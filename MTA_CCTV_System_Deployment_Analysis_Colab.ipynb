# %% [markdown]
# # 📓 CCTV System Deployment & Network Coverage Analysis
#
# This notebook demonstrates the complete process of data cleaning, analysis, and visualization for NYC Transit Subway Entrance and Exit Data. We will generate meaningful insights to help plan an efficient CCTV deployment system.

# %% [markdown]
# ### Step 1: Data Cleaning & Preparation
# ### Load the Dataset

# %%
import pandas as pd

# Upload the Excel file (Use the file upload button on Colab)
from google.colab import files
uploaded = files.upload()

# Load the dataset
file_path = list(uploaded.keys())[0]  # Get the uploaded file name
dataset = pd.read_excel(file_path, sheet_name='Cleaned Data')

# Display the first few rows
dataset.head()
# Out:
#      <input type="file" id="files-709e6403-0f1b-4398-a175-0020a6cd0aae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-709e6403-0f1b-4398-a175-0020a6cd0aae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Inspect the Dataset

# %%
# Check basic information
dataset.info()

# Display column names
print(dataset.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1868 entries, 0 to 1867
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Division            1868 non-null   object
#  1   Line                1868 non-null   object
#  2   Station Name        1868 non-null   object
#  3   Station Latitude    1868 non-null   float64
#  4   Station Longitude   1868 non-null   float64
#  5   ADA                 1868 non-null   bool
#  6   Free Crossover      1868 non-null   bool
#  7   North South Street  1839 non-null   object
#  8   East West Street    1833 non-null   object
#  9   Entrance Latitude   1868 non-null   float64
#  10  Entrance Longitude  1868 non-null   float64
# dtypes: bool(2), float64(4), object(5)
# memory usage: 135.1+ KB
# Index(['Division', 'Line', 'Station Name', 'Station Latitude',
#        'Station Longitude', 'ADA', 'Free Crossover', 'North South Street',
# ...

# %% [markdown]
# ### Select Relevant Columns

# %%
columns_to_keep = [
    "Division", "Line", "Station Name", "Station Latitude", "Station Longitude",
    "ADA", "Free Crossover", "North South Street", "East West Street",
    "Entrance Latitude", "Entrance Longitude"
]

cleaned_dataset = dataset[columns_to_keep]
cleaned_dataset.head()
# Out:
#   Division      Line Station Name  Station Latitude  Station Longitude    ADA  \
# 0      BMT  4 Avenue      25th St         40.660397         -73.998091  False
# 1      BMT  4 Avenue      25th St         40.660397         -73.998091  False
# 2      BMT  4 Avenue      36th St         40.655144         -74.003549  False
# 3      BMT  4 Avenue      36th St         40.655144         -74.003549  False
# 4      BMT  4 Avenue      36th St         40.655144         -74.003549  False
#
#    Free Crossover North South Street East West Street  Entrance Latitude  \
# 0           False            4th Ave          25th St          40.660489
# 1           False            4th Ave          25th St          40.660323
# 2            True            4th Ave          36th St          40.654676
# 3            True            4th Ave          36th St          40.654365
# 4            True            4th Ave          36th St          40.654490
#
#    Entrance Longitude
# 0          -73.998220
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
# Check for missing values
cleaned_dataset.isnull().sum()

# Remove rows with missing essential data
cleaned_dataset.dropna(subset=["Station Name", "Station Latitude", "Station Longitude"], inplace=True)

# %% [markdown]
# ## Step 2: Data Analysis & Visualization

# %%
# Count Entrances Per Station
entrance_count = cleaned_dataset.groupby('Station Name').size().reset_index(name='Entrance Count')
entrance_count.head()
# Out:
#                   Station Name  Entrance Count
# 0                     103rd St              12
# 1            104th St-102nd St               2
# 2           104th St-Oxford Av               2
# 3                     110th St               4
# 4  110th St-Central Park North               2

# %%
# Analyze ADA Accessibility Coverage
ada_coverage = cleaned_dataset.groupby(['Division', 'ADA']).size().reset_index(name='Count')
ada_coverage.head()
# Out:
#   Division    ADA  Count
# 0      BMT  False    382
# 1      BMT   True     60
# 2      IND  False    518
# 3      IND   True    208
# 4      IRT  False    500

# %% [markdown]
# ### Visualize Data

# %%
import matplotlib.pyplot as plt

# Plot: Top 10 Stations by Number of Entrances
top_10 = entrance_count.sort_values(by='Entrance Count', ascending=False).head(10)
plt.figure(figsize=(12, 6))
plt.bar(top_10['Station Name'], top_10['Entrance Count'])
plt.title('Top 10 Stations by Number of Entrances')
plt.xticks(rotation=45)
plt.show()

# %%
# Plot: ADA Accessibility Coverage by Division
ada_coverage_pivot = ada_coverage.pivot(index='Division', columns='ADA', values='Count').fillna(0)
ada_coverage_pivot.plot(kind='bar', figsize=(12, 6))
plt.title('ADA Accessibility Coverage by Division')
plt.xlabel('Division')
plt.ylabel('Count of Entrances')
plt.xticks(rotation=0)
plt.show()
